# %% [markdown]
# # Step 2

# %%
# Import libraries

import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import math
import random
import pulp

# %%
# Generating Points and Distances

n=12
random.seed(20246862)

def dist(p1, p2):
    (x1, y1) = p1
    (x2, y2) = p2
    return int(math.sqrt((x1-x2)**2+(y1-y2)**2)*700)

# %%
def x_of(p):
    (x,_)=p
    return x
def y_of(p):
    (_, y)=p
    return y

# %%
P = []
eps = 0.05
while len(P)<n:
    i=len(P)
    x0=random.random()
    if x0<eps or x0>1-eps:
        continue
    y0=random.random()
    if y0<eps or y0>1-eps:
        continue
    P.append((x0,y0))
    for j in range(0,i):
        if dist(P[i],P[j])<50:
            P=P[:-1]
            break
town = [ chr(ord('A')+i) for i in range(0,n) ]

# %%
P
# Out:
# [(0.780677152841719, 0.24768935251489643),
#  (0.6008167803559864, 0.41640173572058525),
#  (0.7024583369166644, 0.828931302861875),
#  (0.8134190736361858, 0.6661570238600951),
#  (0.8909057397782246, 0.22244841870937337),
#  (0.5051656828427308, 0.8053764020364963),
#  (0.27223883533777693, 0.6172355919936735),
#  (0.3248493523899879, 0.8223706118904256),
#  (0.27753712147053833, 0.9012762641076292),
#  (0.39876804690573053, 0.9013481920739925),
#  (0.6684820089960282, 0.6900332371885604),
#  (0.1628215942158382, 0.5188748516716034)]

# %%
town
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L']

# %%
plt.xlim(0,1)
plt.ylim(0,1)
plt.axis('off')
plt.plot([ x for (x,_) in P ],[ y for (_,y) in P ], 'ro')

# %%
# Table of Distances

print("    ", end='')
for j in range(0, n):
    print(f"{town[j]:4s}", end='')
print()
for i in range(0, n):
    print(f"{town[i]:s}", end='')
    for j in range(0, n):
        if i==j:
            print(" ---", end='')
        else:
            print(f"{dist(P[i],P[j]):4d}", end='')
    print()
# Out:
#     A   B   C   D   E   F   G   H   I   J   K   L
# A --- 172 410 293  79 435 439 513 577 529 319 472
# B 172 --- 297 229 244 280 269 343 407 367 197 314
# C 410 297 --- 137 444 139 335 264 301 218 100 435
# D 293 229 137 --- 315 236 380 359 409 333 102 466
# E  79 244 444 315 --- 489 513 577 640 586 362 550
# F 435 280 139 236 489 --- 209 126 172 100 139 312
# G 439 269 335 380 513 209 --- 148 198 217 282 102
# H 513 343 264 359 577 126 148 ---  64  75 257 240
# I 577 407 301 409 640 172 198  64 ---  84 311 279
# J 529 367 218 333 586 100 217  75  84 --- 239 314
# K 319 197 100 102 362 139 282 257 311 239 --- 373
# L 472 314 435 466 550 312 102 240 279 314 373 ---

# %% [markdown]
# # Step 3

# %%
# Creating variables

x = pulp.LpVariable.dicts("x", ( range(0,n), range(0,n) ),
                          lowBound=0, upBound=1, 
                          cat=pulp.LpInteger)

# %%
x
# Out:
# {0: {0: x_0_0,
#   1: x_0_1,
#   2: x_0_2,
#   3: x_0_3,
#   4: x_0_4,
#   5: x_0_5,
#   6: x_0_6,
#   7: x_0_7,
#   8: x_0_8,
#   9: x_0_9,
#   10: x_0_10,
#   11: x_0_11},
#  1: {0: x_1_0,
#   1: x_1_1,
#   2: x_1_2,
#   3: x_1_3,
#   4: x_1_4,
#   5: x_1_5,
#   6: x_1_6,
#   7: x_1_7,
#   8: x_1_8,
#   9: x_1_9,
#   10: x_1_10,
#   11: x_1_11},
#  2: {0: x_2_0,
#   1: x_2_1,
#   2: x_2_2,
#   3: x_2_3,
#   4: x_2_4,
#   5: x_2_5,
#   6: x_2_6,
#   7: x_2_7,
#   8: x_2_8,
#   9: x_2_9,
#   10: x_2_10,
#   11: x_2_11},
#  3: {0: x_3_0,
#   1: x_3_1,
#   2: x_3_2,
#   3: x_3_3,
#   4: x_3_4,
#   5: x_3_5,
#   6: x_3_6,
#   7: x_3_7,
#   8: x_3_8,
#   9: x_3_9,
#   10: x_3_10,
#   11: x_3_11},
#  4: {0: x_4_0,
#   1: x_4_1,
#   2: x_4_2,
#   3: x_4_3,
#   4: x_4_4,
#   5: x_4_5,
#   6: x_4_6,
#   7: x_4_7,
#   8: x_4_8,
#   9: x_4_9,
#   10: x_4_10,
#   11: x_4_11},
#  5: {0: x_5_0,
#   1: x_5_1,
#   2: x_5_2,
#   3: x_5_3,
#   4: x_5_4,
#   5: x_5_5,
#   6: x_5_6,
#   7: x_5_7,
#   8: x_5_8,
#   9: x_5_9,
#   10: x_5_10,
#   11: x_5_11},
#  6: {0: x_6_0,
#   1: x_6_1,
#   2: x_6_2,
#   3: x_6_3,
#   4: x_6_4,
#   5: x_6_5,
#   6: x_6_6,
#   7: x_6_7,
#   8: x_6_8,
#   9: x_6_9,
#   10: x_6_10,
#   11: x_6_11},
#  7: {0: x_7_0,
#   1: x_7_1,
#   2: x_7_2,
#   3: x_7_3,
#   4: x_7_4,
#   5: x_7_5,
#   6: x_7_6,
#   7: x_7_7,
#   8: x_7_8,
#   9: x_7_9,
#   10: x_7_10,
#   11: x_7_11},
#  8: {0: x_8_0,
#   1: x_8_1,
#   2: x_8_2,
#   3: x_8_3,
#   4: x_8_4,
#   5: x_8_5,
#   6: x_8_6,
#   7: x_8_7,
#   8: x_8_8,
#   9: x_8_9,
#   10: x_8_10,
#   11: x_8_11},
#  9: {0: x_9_0,
#   1: x_9_1,
#   2: x_9_2,
#   3: x_9_3,
#   4: x_9_4,
#   5: x_9_5,
#   6: x_9_6,
#   7: x_9_7,
#   8: x_9_8,
#   9: x_9_9,
#   10: x_9_10,
#   11: x_9_11},
#  10: {0: x_10_0,
#   1: x_10_1,
#   2: x_10_2,
#   3: x_10_3,
#   4: x_10_4,
#   5: x_10_5,
#   6: x_10_6,
#   7: x_10_7,
#   8: x_10_8,
#   9: x_10_9,
#   10: x_10_10,
#   11: x_10_11},
#  11: {0: x_11_0,
#   1: x_11_1,
#   2: x_11_2,
#   3: x_11_3,
#   4: x_11_4,
#   5: x_11_5,
#   6: x_11_6,
#   7: x_11_7,
#   8: x_11_8,
#   9: x_11_9,
#   10: x_11_10,
#   11: x_11_11}}

# %%
# We need to keep track of the order in the tour to eliminate the possibility of subtours

u = pulp.LpVariable.dicts('u', (i for i in range(0,n)), lowBound=0, upBound=n, cat=pulp.LpInteger)

# %%
u
# Out:
# {0: u_0,
#  1: u_1,
#  2: u_2,
#  3: u_3,
#  4: u_4,
#  5: u_5,
#  6: u_6,
#  7: u_7,
#  8: u_8,
#  9: u_9,
#  10: u_10,
#  11: u_11}

# %%
# Define Problem

problem = pulp.LpProblem("TSP",pulp.LpMinimize)

# %%
problem += pulp.lpSum([ dist(P[i],P[j])*x[i][j] 
                        for i in range(0,n)
                            for j in range(0,n)])

# %%
# Add Constraints (Encoding)
# Every Town is visited only once

for j in range(0,n):
    problem += pulp.lpSum([ x[i][j] 
                         for i in range(0,n) 
                             if i!=j
                       ]) ==1
constraints = n

# %%
# Every town was left only once:

for i in range(0,n):
    problem += pulp.lpSum([ x[i][j] 
                         for j in range(0,n)
                             if i!=j
                       ]) ==1
constraints += n

# %%
# Eliminate subtour
    
for i in range(0,n):
    for j in range(0,n):
        if i != j and (i != 0 and j != 0):
            problem += u[i] - u[j] <= n * (1 - x[i][j]) - 1
    constraints += n

# %%
print(f"{constraints:d} Constraints")
# Out:
# 168 Constraints

# %%
# Check the encoding

problem
# Out:
# TSP:
# MINIMIZE
# 172*x_0_1 + 319*x_0_10 + 472*x_0_11 + 410*x_0_2 + 293*x_0_3 + 79*x_0_4 + 435*x_0_5 + 439*x_0_6 + 513*x_0_7 + 577*x_0_8 + 529*x_0_9 + 319*x_10_0 + 197*x_10_1 + 373*x_10_11 + 100*x_10_2 + 102*x_10_3 + 362*x_10_4 + 139*x_10_5 + 282*x_10_6 + 257*x_10_7 + 311*x_10_8 + 239*x_10_9 + 472*x_11_0 + 314*x_11_1 + 373*x_11_10 + 435*x_11_2 + 466*x_11_3 + 550*x_11_4 + 312*x_11_5 + 102*x_11_6 + 240*x_11_7 + 279*x_11_8 + 314*x_11_9 + 172*x_1_0 + 197*x_1_10 + 314*x_1_11 + 297*x_1_2 + 229*x_1_3 + 244*x_1_4 + 280*x_1_5 + 269*x_1_6 + 343*x_1_7 + 407*x_1_8 + 367*x_1_9 + 410*x_2_0 + 297*x_2_1 + 100*x_2_10 + 435*x_2_11 + 137*x_2_3 + 444*x_2_4 + 139*x_2_5 + 335*x_2_6 + 264*x_2_7 + 301*x_2_8 + 218*x_2_9 + 293*x_3_0 + 229*x_3_1 + 102*x_3_10 + 466*x_3_11 + 137*x_3_2 + 315*x_3_4 + 236*x_3_5 + 380*x_3_6 + 359*x_3_7 + 409*x_3_8 + 333*x_3_9 + 79*x_4_0 + 244*x_4_1 + 362*x_4_10 + 550*x_4_11 + 444*x_4_2 + 315*x_4_3 + 489*x_4_5 + 513*x_4_6 + 577*x_4_7 + 640*x_4_8 + 586*x_4_9 + 435*x_5_0 + 280*x_5_1 + 139*x_5_10 + 312*x_5_11 + 139*x_5_2 + 236*x_5_3 + 489*x_5_4 + 209*x_5_6 + 126*x_5_7 + 172*x_5_8 + 100*x_5_9 + 439*x_6_0 + 269*x_6_1 + 282*x_6_10 + 102*x_6_11 + 335*x_6_2 + 380*x_6_3 + 513*x_6_4 + 209*x_6_5 + 148*x_6_7 + 198*x_6_8 + 217*x_6_9 + 513*x_7_0 + 343*x_7_1 + 257*x_7_10 + 240*x_7_11 + 264*x_7_2 + 359*x_7_3 + 577*x_7_4 + 126*x_7_5 + 148*x_7_6 + 64*x_7_8 + 75*x_7_9 + 577*x_8_0 + 407*x_8_1 + 311*x_8_10 + 279*x_8_11 + 301*x_8_2 + 409*x_8_3 + 640*x_8_4 + 172*x_8_5 + 198*x_8_6 + 64*x_8_7 + 84*x_8_9 + 529*x_9_0 + 367*x_9_1 + 239*x_9_10 + 314*x_9_11 + 218*x_9_2 + 333*x_9_3 + 586*x_9_4 + 100*x_9_5 + 217*x_9_6 + 75*x_9_7 + 84*x_9_8 + 0
# SUBJECT TO
# _C1: x_10_0 + x_11_0 + x_1_0 + x_2_0 + x_3_0 + x_4_0 + x_5_0 + x_6_0 + x_7_0
#  + x_8_0 + x_9_0 = 1
#
# _C2: x_0_1 + x_10_1 + x_11_1 + x_2_1 + x_3_1 + x_4_1 + x_5_1 + x_6_1 + x_7_1
#  + x_8_1 + x_9_1 = 1
#
# _C3: x_0_2 + x_10_2 + x_11_2 + x_1_2 + x_3_2 + x_4_2 + x_5_2 + x_6_2 + x_7_2
#  + x_8_2 + x_9_2 = 1
#
# _C4: x_0_3 + x_10_3 + x_11_3 + x_1_3 + x_2_3 + x_4_3 + x_5_3 + x_6_3 + x_7_3
#  + x_8_3 + x_9_3 = 1
#
# _C5: x_0_4 + x_10_4 + x_11_4 + x_1_4 + x_2_4 + x_3_4 + x_5_4 + x_6_4 + x_7_4
#  + x_8_4 + x_9_4 = 1
#
# _C6: x_0_5 + x_10_5 + x_11_5 + x_1_5 + x_2_5 + x_3_5 + x_4_5 + x_6_5 + x_7_5
#  + x_8_5 + x_9_5 = 1
#
# _C7: x_0_6 + x_10_6 + x_11_6 + x_1_6 + x_2_6 + x_3_6 + x_4_6 + x_5_6 + x_7_6
#  + x_8_6 + x_9_6 = 1
#
# _C8: x_0_7 + x_10_7 + x_11_7 + x_1_7 + x_2_7 + x_3_7 + x_4_7 + x_5_7 + x_6_7
#  + x_8_7 + x_9_7 = 1
#
# _C9: x_0_8 + x_10_8 + x_11_8 + x_1_8 + x_2_8 + x_3_8 + x_4_8 + x_5_8 + x_6_8
#  + x_7_8 + x_9_8 = 1
#
# _C10: x_0_9 + x_10_9 + x_11_9 + x_1_9 + x_2_9 + x_3_9 + x_4_9 + x_5_9 + x_6_9
#  + x_7_9 + x_8_9 = 1
#
# _C11: x_0_10 + x_11_10 + x_1_10 + x_2_10 + x_3_10 + x_4_10 + x_5_10 + x_6_10
#  + x_7_10 + x_8_10 + x_9_10 = 1
#
# _C12: x_0_11 + x_10_11 + x_1_11 + x_2_11 + x_3_11 + x_4_11 + x_5_11 + x_6_11
#  + x_7_11 + x_8_11 + x_9_11 = 1
#
# _C13: x_0_1 + x_0_10 + x_0_11 + x_0_2 + x_0_3 + x_0_4 + x_0_5 + x_0_6 + x_0_7
#  + x_0_8 + x_0_9 = 1
#
# _C14: x_1_0 + x_1_10 + x_1_11 + x_1_2 + x_1_3 + x_1_4 + x_1_5 + x_1_6 + x_1_7
#  + x_1_8 + x_1_9 = 1
#
# _C15: x_2_0 + x_2_1 + x_2_10 + x_2_11 + x_2_3 + x_2_4 + x_2_5 + x_2_6 + x_2_7
#  + x_2_8 + x_2_9 = 1
#
# _C16: x_3_0 + x_3_1 + x_3_10 + x_3_11 + x_3_2 + x_3_4 + x_3_5 + x_3_6 + x_3_7
#  + x_3_8 + x_3_9 = 1
#
# _C17: x_4_0 + x_4_1 + x_4_10 + x_4_11 + x_4_2 + x_4_3 + x_4_5 + x_4_6 + x_4_7
#  + x_4_8 + x_4_9 = 1
#
# _C18: x_5_0 + x_5_1 + x_5_10 + x_5_11 + x_5_2 + x_5_3 + x_5_4 + x_5_6 + x_5_7
#  + x_5_8 + x_5_9 = 1
#
# _C19: x_6_0 + x_6_1 + x_6_10 + x_6_11 + x_6_2 + x_6_3 + x_6_4 + x_6_5 + x_6_7
#  + x_6_8 + x_6_9 = 1
#
# _C20: x_7_0 + x_7_1 + x_7_10 + x_7_11 + x_7_2 + x_7_3 + x_7_4 + x_7_5 + x_7_6
#  + x_7_8 + x_7_9 = 1
#
# _C21: x_8_0 + x_8_1 + x_8_10 + x_8_11 + x_8_2 + x_8_3 + x_8_4 + x_8_5 + x_8_6
#  + x_8_7 + x_8_9 = 1
#
# _C22: x_9_0 + x_9_1 + x_9_10 + x_9_11 + x_9_2 + x_9_3 + x_9_4 + x_9_5 + x_9_6
#  + x_9_7 + x_9_8 = 1
#
# _C23: x_10_0 + x_10_1 + x_10_11 + x_10_2 + x_10_3 + x_10_4 + x_10_5 + x_10_6
#  + x_10_7 + x_10_8 + x_10_9 = 1
#
# _C24: x_11_0 + x_11_1 + x_11_10 + x_11_2 + x_11_3 + x_11_4 + x_11_5 + x_11_6
#  + x_11_7 + x_11_8 + x_11_9 = 1
#
# _C25: u_1 - u_2 + 12 x_1_2 <= 11
#
# _C26: u_1 - u_3 + 12 x_1_3 <= 11
#
# _C27: u_1 - u_4 + 12 x_1_4 <= 11
#
# _C28: u_1 - u_5 + 12 x_1_5 <= 11
#
# _C29: u_1 - u_6 + 12 x_1_6 <= 11
#
# _C30: u_1 - u_7 + 12 x_1_7 <= 11
#
# _C31: u_1 - u_8 + 12 x_1_8 <= 11
#
# _C32: u_1 - u_9 + 12 x_1_9 <= 11
#
# _C33: u_1 - u_10 + 12 x_1_10 <= 11
#
# _C34: u_1 - u_11 + 12 x_1_11 <= 11
#
# _C35: - u_1 + u_2 + 12 x_2_1 <= 11
#
# _C36: u_2 - u_3 + 12 x_2_3 <= 11
#
# _C37: u_2 - u_4 + 12 x_2_4 <= 11
#
# _C38: u_2 - u_5 + 12 x_2_5 <= 11
#
# _C39: u_2 - u_6 + 12 x_2_6 <= 11
#
# _C40: u_2 - u_7 + 12 x_2_7 <= 11
#
# _C41: u_2 - u_8 + 12 x_2_8 <= 11
#
# _C42: u_2 - u_9 + 12 x_2_9 <= 11
#
# _C43: - u_10 + u_2 + 12 x_2_10 <= 11
#
# _C44: - u_11 + u_2 + 12 x_2_11 <= 11
#
# _C45: - u_1 + u_3 + 12 x_3_1 <= 11
#
# _C46: - u_2 + u_3 + 12 x_3_2 <= 11
#
# _C47: u_3 - u_4 + 12 x_3_4 <= 11
#
# _C48: u_3 - u_5 + 12 x_3_5 <= 11
#
# _C49: u_3 - u_6 + 12 x_3_6 <= 11
#
# _C50: u_3 - u_7 + 12 x_3_7 <= 11
#
# _C51: u_3 - u_8 + 12 x_3_8 <= 11
#
# _C52: u_3 - u_9 + 12 x_3_9 <= 11
#
# _C53: - u_10 + u_3 + 12 x_3_10 <= 11
#
# _C54: - u_11 + u_3 + 12 x_3_11 <= 11
#
# _C55: - u_1 + u_4 + 12 x_4_1 <= 11
#
# _C56: - u_2 + u_4 + 12 x_4_2 <= 11
#
# _C57: - u_3 + u_4 + 12 x_4_3 <= 11
#
# _C58: u_4 - u_5 + 12 x_4_5 <= 11
#
# _C59: u_4 - u_6 + 12 x_4_6 <= 11
#
# _C60: u_4 - u_7 + 12 x_4_7 <= 11
#
# _C61: u_4 - u_8 + 12 x_4_8 <= 11
#
# _C62: u_4 - u_9 + 12 x_4_9 <= 11
#
# _C63: - u_10 + u_4 + 12 x_4_10 <= 11
#
# _C64: - u_11 + u_4 + 12 x_4_11 <= 11
#
# _C65: - u_1 + u_5 + 12 x_5_1 <= 11
#
# _C66: - u_2 + u_5 + 12 x_5_2 <= 11
#
# _C67: - u_3 + u_5 + 12 x_5_3 <= 11
#
# _C68: - u_4 + u_5 + 12 x_5_4 <= 11
#
# _C69: u_5 - u_6 + 12 x_5_6 <= 11
#
# _C70: u_5 - u_7 + 12 x_5_7 <= 11
#
# _C71: u_5 - u_8 + 12 x_5_8 <= 11
#
# _C72: u_5 - u_9 + 12 x_5_9 <= 11
#
# _C73: - u_10 + u_5 + 12 x_5_10 <= 11
#
# _C74: - u_11 + u_5 + 12 x_5_11 <= 11
#
# _C75: - u_1 + u_6 + 12 x_6_1 <= 11
#
# _C76: - u_2 + u_6 + 12 x_6_2 <= 11
#
# _C77: - u_3 + u_6 + 12 x_6_3 <= 11
#
# _C78: - u_4 + u_6 + 12 x_6_4 <= 11
#
# _C79: - u_5 + u_6 + 12 x_6_5 <= 11
#
# _C80: u_6 - u_7 + 12 x_6_7 <= 11
#
# _C81: u_6 - u_8 + 12 x_6_8 <= 11
#
# _C82: u_6 - u_9 + 12 x_6_9 <= 11
#
# _C83: - u_10 + u_6 + 12 x_6_10 <= 11
#
# _C84: - u_11 + u_6 + 12 x_6_11 <= 11
#
# _C85: - u_1 + u_7 + 12 x_7_1 <= 11
#
# _C86: - u_2 + u_7 + 12 x_7_2 <= 11
#
# _C87: - u_3 + u_7 + 12 x_7_3 <= 11
#
# _C88: - u_4 + u_7 + 12 x_7_4 <= 11
#
# _C89: - u_5 + u_7 + 12 x_7_5 <= 11
#
# _C90: - u_6 + u_7 + 12 x_7_6 <= 11
#
# _C91: u_7 - u_8 + 12 x_7_8 <= 11
#
# _C92: u_7 - u_9 + 12 x_7_9 <= 11
#
# _C93: - u_10 + u_7 + 12 x_7_10 <= 11
#
# _C94: - u_11 + u_7 + 12 x_7_11 <= 11
#
# _C95: - u_1 + u_8 + 12 x_8_1 <= 11
#
# _C96: - u_2 + u_8 + 12 x_8_2 <= 11
#
# _C97: - u_3 + u_8 + 12 x_8_3 <= 11
#
# _C98: - u_4 + u_8 + 12 x_8_4 <= 11
#
# _C99: - u_5 + u_8 + 12 x_8_5 <= 11
#
# _C100: - u_6 + u_8 + 12 x_8_6 <= 11
#
# _C101: - u_7 + u_8 + 12 x_8_7 <= 11
#
# _C102: u_8 - u_9 + 12 x_8_9 <= 11
#
# _C103: - u_10 + u_8 + 12 x_8_10 <= 11
#
# _C104: - u_11 + u_8 + 12 x_8_11 <= 11
#
# _C105: - u_1 + u_9 + 12 x_9_1 <= 11
#
# _C106: - u_2 + u_9 + 12 x_9_2 <= 11
#
# _C107: - u_3 + u_9 + 12 x_9_3 <= 11
#
# _C108: - u_4 + u_9 + 12 x_9_4 <= 11
#
# _C109: - u_5 + u_9 + 12 x_9_5 <= 11
#
# _C110: - u_6 + u_9 + 12 x_9_6 <= 11
#
# _C111: - u_7 + u_9 + 12 x_9_7 <= 11
#
# _C112: - u_8 + u_9 + 12 x_9_8 <= 11
#
# _C113: - u_10 + u_9 + 12 x_9_10 <= 11
#
# _C114: - u_11 + u_9 + 12 x_9_11 <= 11
#
# _C115: - u_1 + u_10 + 12 x_10_1 <= 11
#
# _C116: u_10 - u_2 + 12 x_10_2 <= 11
#
# _C117: u_10 - u_3 + 12 x_10_3 <= 11
#
# _C118: u_10 - u_4 + 12 x_10_4 <= 11
#
# _C119: u_10 - u_5 + 12 x_10_5 <= 11
#
# _C120: u_10 - u_6 + 12 x_10_6 <= 11
#
# _C121: u_10 - u_7 + 12 x_10_7 <= 11
#
# _C122: u_10 - u_8 + 12 x_10_8 <= 11
#
# _C123: u_10 - u_9 + 12 x_10_9 <= 11
#
# _C124: u_10 - u_11 + 12 x_10_11 <= 11
#
# _C125: - u_1 + u_11 + 12 x_11_1 <= 11
#
# _C126: u_11 - u_2 + 12 x_11_2 <= 11
#
# _C127: u_11 - u_3 + 12 x_11_3 <= 11
#
# _C128: u_11 - u_4 + 12 x_11_4 <= 11
#
# _C129: u_11 - u_5 + 12 x_11_5 <= 11
#
# _C130: u_11 - u_6 + 12 x_11_6 <= 11
#
# _C131: u_11 - u_7 + 12 x_11_7 <= 11
#
# _C132: u_11 - u_8 + 12 x_11_8 <= 11
#
# _C133: u_11 - u_9 + 12 x_11_9 <= 11
#
# _C134: - u_10 + u_11 + 12 x_11_10 <= 11
#
# VARIABLES
# 0 <= u_1 <= 12 Integer
# 0 <= u_10 <= 12 Integer
# 0 <= u_11 <= 12 Integer
# 0 <= u_2 <= 12 Integer
# 0 <= u_3 <= 12 Integer
# 0 <= u_4 <= 12 Integer
# 0 <= u_5 <= 12 Integer
# 0 <= u_6 <= 12 Integer
# 0 <= u_7 <= 12 Integer
# 0 <= u_8 <= 12 Integer
# 0 <= u_9 <= 12 Integer
# 0 <= x_0_1 <= 1 Integer
# 0 <= x_0_10 <= 1 Integer
# 0 <= x_0_11 <= 1 Integer
# 0 <= x_0_2 <= 1 Integer
# 0 <= x_0_3 <= 1 Integer
# 0 <= x_0_4 <= 1 Integer
# 0 <= x_0_5 <= 1 Integer
# 0 <= x_0_6 <= 1 Integer
# 0 <= x_0_7 <= 1 Integer
# 0 <= x_0_8 <= 1 Integer
# 0 <= x_0_9 <= 1 Integer
# 0 <= x_10_0 <= 1 Integer
# 0 <= x_10_1 <= 1 Integer
# 0 <= x_10_11 <= 1 Integer
# 0 <= x_10_2 <= 1 Integer
# 0 <= x_10_3 <= 1 Integer
# 0 <= x_10_4 <= 1 Integer
# 0 <= x_10_5 <= 1 Integer
# 0 <= x_10_6 <= 1 Integer
# 0 <= x_10_7 <= 1 Integer
# 0 <= x_10_8 <= 1 Integer
# 0 <= x_10_9 <= 1 Integer
# 0 <= x_11_0 <= 1 Integer
# 0 <= x_11_1 <= 1 Integer
# 0 <= x_11_10 <= 1 Integer
# 0 <= x_11_2 <= 1 Integer
# 0 <= x_11_3 <= 1 Integer
# 0 <= x_11_4 <= 1 Integer
# 0 <= x_11_5 <= 1 Integer
# 0 <= x_11_6 <= 1 Integer
# 0 <= x_11_7 <= 1 Integer
# 0 <= x_11_8 <= 1 Integer
# 0 <= x_11_9 <= 1 Integer
# 0 <= x_1_0 <= 1 Integer
# 0 <= x_1_10 <= 1 Integer
# 0 <= x_1_11 <= 1 Integer
# 0 <= x_1_2 <= 1 Integer
# 0 <= x_1_3 <= 1 Integer
# 0 <= x_1_4 <= 1 Integer
# 0 <= x_1_5 <= 1 Integer
# 0 <= x_1_6 <= 1 Integer
# 0 <= x_1_7 <= 1 Integer
# 0 <= x_1_8 <= 1 Integer
# 0 <= x_1_9 <= 1 Integer
# 0 <= x_2_0 <= 1 Integer
# 0 <= x_2_1 <= 1 Integer
# 0 <= x_2_10 <= 1 Integer
# 0 <= x_2_11 <= 1 Integer
# 0 <= x_2_3 <= 1 Integer
# 0 <= x_2_4 <= 1 Integer
# 0 <= x_2_5 <= 1 Integer
# 0 <= x_2_6 <= 1 Integer
# 0 <= x_2_7 <= 1 Integer
# 0 <= x_2_8 <= 1 Integer
# 0 <= x_2_9 <= 1 Integer
# 0 <= x_3_0 <= 1 Integer
# 0 <= x_3_1 <= 1 Integer
# 0 <= x_3_10 <= 1 Integer
# 0 <= x_3_11 <= 1 Integer
# 0 <= x_3_2 <= 1 Integer
# 0 <= x_3_4 <= 1 Integer
# 0 <= x_3_5 <= 1 Integer
# 0 <= x_3_6 <= 1 Integer
# 0 <= x_3_7 <= 1 Integer
# 0 <= x_3_8 <= 1 Integer
# 0 <= x_3_9 <= 1 Integer
# 0 <= x_4_0 <= 1 Integer
# 0 <= x_4_1 <= 1 Integer
# 0 <= x_4_10 <= 1 Integer
# 0 <= x_4_11 <= 1 Integer
# 0 <= x_4_2 <= 1 Integer
# 0 <= x_4_3 <= 1 Integer
# 0 <= x_4_5 <= 1 Integer
# 0 <= x_4_6 <= 1 Integer
# 0 <= x_4_7 <= 1 Integer
# 0 <= x_4_8 <= 1 Integer
# 0 <= x_4_9 <= 1 Integer
# 0 <= x_5_0 <= 1 Integer
# 0 <= x_5_1 <= 1 Integer
# 0 <= x_5_10 <= 1 Integer
# 0 <= x_5_11 <= 1 Integer
# 0 <= x_5_2 <= 1 Integer
# 0 <= x_5_3 <= 1 Integer
# 0 <= x_5_4 <= 1 Integer
# 0 <= x_5_6 <= 1 Integer
# 0 <= x_5_7 <= 1 Integer
# 0 <= x_5_8 <= 1 Integer
# 0 <= x_5_9 <= 1 Integer
# 0 <= x_6_0 <= 1 Integer
# 0 <= x_6_1 <= 1 Integer
# 0 <= x_6_10 <= 1 Integer
# 0 <= x_6_11 <= 1 Integer
# 0 <= x_6_2 <= 1 Integer
# 0 <= x_6_3 <= 1 Integer
# 0 <= x_6_4 <= 1 Integer
# 0 <= x_6_5 <= 1 Integer
# 0 <= x_6_7 <= 1 Integer
# 0 <= x_6_8 <= 1 Integer
# 0 <= x_6_9 <= 1 Integer
# 0 <= x_7_0 <= 1 Integer
# 0 <= x_7_1 <= 1 Integer
# 0 <= x_7_10 <= 1 Integer
# 0 <= x_7_11 <= 1 Integer
# 0 <= x_7_2 <= 1 Integer
# 0 <= x_7_3 <= 1 Integer
# 0 <= x_7_4 <= 1 Integer
# 0 <= x_7_5 <= 1 Integer
# 0 <= x_7_6 <= 1 Integer
# 0 <= x_7_8 <= 1 Integer
# 0 <= x_7_9 <= 1 Integer
# 0 <= x_8_0 <= 1 Integer
# 0 <= x_8_1 <= 1 Integer
# 0 <= x_8_10 <= 1 Integer
# 0 <= x_8_11 <= 1 Integer
# 0 <= x_8_2 <= 1 Integer
# 0 <= x_8_3 <= 1 Integer
# 0 <= x_8_4 <= 1 Integer
# 0 <= x_8_5 <= 1 Integer
# 0 <= x_8_6 <= 1 Integer
# 0 <= x_8_7 <= 1 Integer
# 0 <= x_8_9 <= 1 Integer
# 0 <= x_9_0 <= 1 Integer
# 0 <= x_9_1 <= 1 Integer
# 0 <= x_9_10 <= 1 Integer
# 0 <= x_9_11 <= 1 Integer
# 0 <= x_9_2 <= 1 Integer
# 0 <= x_9_3 <= 1 Integer
# 0 <= x_9_4 <= 1 Integer
# 0 <= x_9_5 <= 1 Integer
# 0 <= x_9_6 <= 1 Integer
# 0 <= x_9_7 <= 1 Integer
# 0 <= x_9_8 <= 1 Integer

# %%
# Solve Problem and Display Solution

problem.solve()
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/hanisibr/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/5t/7h86v1rd1sg2cp_m3c7mtv8r0000gn/T/4c2c746242254228a552979a17bd2e60-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/5t/7h86v1rd1sg2cp_m3c7mtv8r0000gn/T/4c2c746242254228a552979a17bd2e60-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 139 COLUMNS
# At line 1152 RHS
# At line 1287 BOUNDS
# At line 1431 ENDATA
# Problem MODEL has 134 rows, 143 columns and 594 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1380 - 0.00 seconds
# Cgl0004I processed model has 134 rows, 143 columns (143 integer (132 of which binary)) and 594 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 10 integers unsatisfied sum - 1.66667
# Cbc0038I Pass   1: suminf.    1.66667 (10) obj. 1426 iterations 21
# Cbc0038I Pass   2: suminf.    4.89744 (22) obj. 1816.15 iterations 29
# Cbc0038I Pass   3: suminf.    2.00000 (9) obj. 1662.17 iterations 20
# Cbc0038I Pass   4: suminf.    1.66667 (9) obj. 1660.83 iterations 17
# Cbc0038I Pass   5: suminf.    2.33333 (7) obj. 1923.17 iterations 24
# Cbc0038I Pass   6: suminf.    1.66667 (7) obj. 1983.67 iterations 12
# Cbc0038I Pass   7: suminf.    1.66667 (10) obj. 1953.17 iterations 26
# Cbc0038I Pass   8: suminf.    1.66667 (9) obj. 1792.33 iterations 26
# Cbc0038I Pass   9: suminf.    1.66667 (12) obj. 1853.92 iterations 28
# Cbc0038I Pass  10: suminf.    3.33333 (18) obj. 1840.17 iterations 15
# Cbc0038I Pass  11: suminf.    1.66667 (4) obj. 2139.5 iterations 22
# Cbc0038I Pass  12: suminf.    2.95238 (18) obj. 2149.44 iterations 13
# Cbc0038I Pass  13: suminf.    2.00000 (7) obj. 2395.33 iterations 26
# Cbc0038I Pass  14: suminf.    2.33333 (18) obj. 2472.25 iterations 37
# Cbc0038I Pass  15: suminf.    4.16667 (13) obj. 2216.12 iterations 35
# Cbc0038I Pass  16: suminf.    1.66667 (4) obj. 2266.75 iterations 7
# Cbc0038I Pass  17: suminf.    2.33333 (12) obj. 2271.44 iterations 28
# Cbc0038I Pass  18: suminf.    1.66667 (4) obj. 2342.67 iterations 20
# Cbc0038I Pass  19: suminf.    1.66667 (8) obj. 2329.67 iterations 20
# Cbc0038I Pass  20: suminf.    1.66667 (7) obj. 2351 iterations 23
# Cbc0038I Pass  21: suminf.    3.66667 (12) obj. 2306.11 iterations 11
# Cbc0038I Pass  22: suminf.    3.66667 (12) obj. 2306.11 iterations 4
# Cbc0038I Pass  23: suminf.    1.66667 (11) obj. 2334.5 iterations 22
# Cbc0038I Pass  24: suminf.    2.00000 (4) obj. 2367.5 iterations 31
# Cbc0038I Pass  25: suminf.    1.66667 (4) obj. 2348.67 iterations 15
# Cbc0038I Pass  26: suminf.    1.66667 (9) obj. 2347.33 iterations 21
# Cbc0038I Pass  27: suminf.    3.00000 (16) obj. 2470.47 iterations 21
# Cbc0038I Pass  28: suminf.    1.66667 (11) obj. 2482.83 iterations 11
# Cbc0038I Pass  29: suminf.    2.00000 (6) obj. 2301.33 iterations 24
# Cbc0038I Pass  30: suminf.    3.33333 (16) obj. 2307.33 iterations 13
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 90 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 134 rows 143 columns, reduced to 59 rows 49 columns
# Cbc0038I Mini branch and bound did not improve solution (0.16 seconds)
# Cbc0038I After 0.16 seconds - Feasibility pump exiting - took 0.10 seconds
# Cbc0031I 7 added rows had average density of 40.285714
# Cbc0013I At root node, 7 cuts changed objective from 1380 to 1540 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 217 row cuts average 2.3 elements, 0 column cuts (0 active)  in 0.053 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 748 row cuts average 114.3 elements, 0 column cuts (0 active)  in 0.042 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.020 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 2 row cuts average 51.0 elements, 0 column cuts (0 active)  in 0.014 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 68 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.027 seconds - new frequency is 1
# Cbc0014I Cut generator 6 (TwoMirCuts) - 247 row cuts average 21.7 elements, 0 column cuts (0 active)  in 0.018 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, 1e+50 best solution, best possible 1540 (0.49 seconds)
# Cbc0016I Integer solution of 2444 found by strong branching after 1894 iterations and 22 nodes (0.66 seconds)
# Cbc0016I Integer solution of 2327 found by strong branching after 1900 iterations and 22 nodes (0.67 seconds)
# Cbc0038I Full problem 134 rows 143 columns, reduced to 17 rows 14 columns
# Cbc0012I Integer solution of 2169 found by DiveCoefficient after 2591 iterations and 35 nodes (0.73 seconds)
# Cbc0016I Integer solution of 2140 found by strong branching after 2890 iterations and 37 nodes (0.76 seconds)
# Cbc0038I Full problem 134 rows 143 columns, reduced to 8 rows 6 columns
# Cbc0016I Integer solution of 2136 found by strong branching after 3484 iterations and 49 nodes (0.82 seconds)
# Cbc0004I Integer solution of 2020 found after 4019 iterations and 61 nodes (0.90 seconds)
# Cbc0038I Full problem 134 rows 143 columns, reduced to 52 rows 13 columns
# Cbc0038I Full problem 134 rows 143 columns, reduced to 72 rows 22 columns
# Cbc0038I Full problem 134 rows 143 columns, reduced to 67 rows 20 columns
# Cbc0038I Full problem 134 rows 143 columns, reduced to 44 rows 23 columns
# Cbc0038I Full problem 134 rows 143 columns, reduced to 81 rows 21 columns
# Cbc0016I Integer solution of 1952 found by strong branching after 35384 iterations and 615 nodes (4.38 seconds)
# Cbc0016I Integer solution of 1922 found by strong branching after 35490 iterations and 621 nodes (4.40 seconds)
# Cbc0016I Integer solution of 1904 found by strong branching after 37306 iterations and 655 nodes (4.58 seconds)
# Cbc0016I Integer solution of 1863 found by strong branching after 39475 iterations and 688 nodes (4.74 seconds)
# Cbc0038I Full problem 134 rows 143 columns, reduced to 54 rows 21 columns
# Cbc0038I Full problem 134 rows 143 columns, reduced to 28 rows 19 columns
# Cbc0016I Integer solution of 1851 found by strong branching after 61004 iterations and 932 nodes (6.61 seconds)
# Cbc0016I Integer solution of 1806 found by strong branching after 61004 iterations and 933 nodes (6.61 seconds)
# Cbc0016I Integer solution of 1802 found by strong branching after 62681 iterations and 952 nodes (6.72 seconds)
# Cbc0010I After 1000 nodes, 4 on tree, 1802 best solution, best possible 1545 (7.13 seconds)
# Cbc0012I Integer solution of 1719 found by DiveCoefficient after 65928 iterations and 1005 nodes (7.18 seconds)
# Cbc0038I Full problem 134 rows 143 columns, reduced to 80 rows 15 columns
# Cbc0001I Search completed - best objective 1719, took 135236 iterations and 5648 nodes (7.94 seconds)
# Cbc0032I Strong branching done 7912 times (104870 iterations), fathomed 84 nodes and fixed 169 variables
# Cbc0041I Maximum depth 21, 3553 variables fixed on reduced cost (complete fathoming 142 times, 4534 nodes taking 61597 iterations)
# Cuts at root node changed objective from 1380 to 1540
# Probing was tried 3086 times and created 25275 cuts of which 0 were active after adding rounds of cuts (0.634 seconds)
# Gomory was tried 2980 times and created 6368 cuts of which 0 were active after adding rounds of cuts (0.494 seconds)
# Knapsack was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.020 seconds)
# Clique was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# MixedIntegerRounding2 was tried 100 times and created 2 cuts of which 0 were active after adding rounds of cuts (0.014 seconds)
# FlowCover was tried 2980 times and created 1240 cuts of which 0 were active after adding rounds of cuts (0.706 seconds)
# TwoMirCuts was tried 2980 times and created 3636 cuts of which 0 were active after adding rounds of cuts (0.420 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
#
# Result - Optimal solution found
#
# Objective value:                1719.00000000
# Enumerated nodes:               5648
# Total iterations:               135236
# Time (CPU seconds):             6.86
# Time (Wallclock seconds):       7.95
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       6.87   (Wallclock seconds):       7.97
# 1

# %%
# Plot the optimal route

def isElem(x, l):
    for i in range(0, len(l)):
        if l[i]==x:
            return True
    return False

# %%
def startpoint(trips):
    for i in range(0,n):
        for t in trips:
            if isElem(i, t):
                break
        else:
            return i

# %%
def totallength(trips):
    s=0
    for i in range(0, len(trips)):
        s += len(trips[i])-1
    return s

# %%
trips = []
while totallength(trips)<n:
    start = startpoint(trips)
    trip = [ start ]
    i = start
    while len(trip) < n-totallength(trips):
        for j in range(0, n):
            if pulp.value(x[i][j])==1:
                trip.append(j)
                i=j
                break        
        if pulp.value(x[trip[-1]][start])==1:
            trip.append(start)
            break
    trips.append(trip)
trips
# Out:
# [[0, 4, 3, 10, 2, 5, 9, 8, 7, 6, 11, 1, 0]]

# %%
obj_func = pulp.value(problem.objective)
obj_func
# Out:
# 1719.0

# %%
def showTrip(t, style, lw=1, ms=5):
    plt.xlim(0,1)
    plt.ylim(0,1)
    plt.axis('off')
    
    for k in range(0,len(t)-1):
        plt.plot([ x_of(t[k]), x_of(t[k+1])], 
                    [ y_of(t[k]), y_of(t[k+1])], style, lw=lw, ms=ms)

# %%
def totalLength(trip):
    sum=0
    for i in range(0, len(trip)-1):
        sum+=dist(trip[i], trip[i+1])
    return sum

# %% [markdown]
# # Step 4

# %%
def nearest(p, x):
    idx=0
    mindist=dist(p[0], x)
    for i in range(1, len(p)):
        d=dist(p[i], x)
        if d<mindist:
            mindist=d
            idx=i
    return p[idx]

# %%
def greedy2(p):
    p = p.copy()
    x = p[0]
    path = [x]
    p.remove(x)
    while len(p)>0:
        x = path[-1]
        xx = nearest(p, x)
        y = path[0]
        yy = nearest(p, y)
        if dist(x, xx)<=dist(y, yy):
            path = path + [xx]
            p.remove(xx)
        else:
            path = [yy] + path
            p.remove(yy)
    path.append(path[0])
    return path

# %%
g=greedy2(P)
totalLength(g)
# Out:
# 2010

# %%
def compareTrips(t1, t2):

    print(f"Length of roundtrip 1 (red):   {totalLength(t1):d}")
    print(f"Length of roundtrip 2 (green): {totalLength(t2):d}")
    
    plt.figure(1)
    showTrip(t1, 'r-o',lw=3, ms=10)
    showTrip(t2, 'g:o',lw=2)

    plt.figure(2)
    showTrip(t2, 'g-o')

# %%
showTrip(g, 'r-o')

# %%
def shortcut(trip):
    # again we make a copy because of in-place changes
    t=trip.copy()
    for i in range(0, len(t)-1):
        for k in range(2, len(t)-i-1):
            a = dist(t[i], t[i+1])
            b = dist(t[i+k], t[i+k+1])
            c = dist(t[i], t[i+k])
            d = dist(t[i+1], t[i+k+1])
            if c+d < a+b:
            #if dist(t[i], t[i+k])+dist(t[i+1], t[i+k+1]) < \
            #        dist(t[i], t[i+1])+dist(t[i+k], t[i+k+1]):
                sub=t[i+1:i+k+1]
                sub.reverse()
                t=t[0:i+1]+sub+t[i+k+1:]
                return t
    return None

# %%
# %%time
g1 = g
g2 = shortcut(g1)
while g2 is not None:
    print(totalLength(g),"reduced to", totalLength(g2))
    g1 = g2
    g2 = shortcut(g1)
improvement = totalLength(g)-totalLength(g1)
compareTrips(g, g1)
# Out:
# 2010 reduced to 1969
# 2010 reduced to 1874
# 2010 reduced to 1869
# 2010 reduced to 1719
# Length of roundtrip 1 (red):   2010
# Length of roundtrip 2 (green): 1719
# CPU times: user 92.3 ms, sys: 8.3 ms, total: 101 ms
# Wall time: 113 ms

# %% [markdown]
# ## References:
# ## C. Horn (2023). Modelling, Simulation and Optimization: Greedy and Heuristics
# ## Kaggle (2020) TSP PuLP Optimization / PyTorch Deep Learning. Available at:[https://www.kaggle.com/code/itoeiji/tsp-pulp-optimization-pytorch-deep-learning]
